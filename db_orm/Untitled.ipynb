# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect("testing.db")
df = pd.read_sql_query("SELECT * from userstesting", con)

# %%
# Out:
#    id       name    lastname           timecreate          timeupdated  age  \
# 0   1        Ted    Champion  2022-02-23 12:27:00  2022-02-23 12:48:00   50
# 1   2    Refugio  Swearingen  2022-02-23 12:27:00                 None   62
# 2   3  Johnathan       Parra  2022-02-23 12:27:00                 None   28
# 3   4     Gussie      Kelley  2022-02-23 12:27:00                 None   21
# 4   5     Susana      Camara  2022-02-23 12:27:00                 None   69
#
#                        company
# 0         Federated Industries
# 1                     Bell Net
# 2    Medicine Signal Solutions
# 3         Systems Net Provider
# 4  Electronics Research People

# %%
df["name"]
# Out:
# 0            Ted
# 1        Refugio
# 2      Johnathan
# 3         Gussie
# 4         Susana
#          ...
# 395        Wanda
# 396      Dolores
# 397        Arlen
# 398     Marcella
# 399        Loren
# Name: name, Length: 400, dtype: object

# %%
df[["age"]].mean()
# Out:
# age    44.645
# dtype: float64

# %%
df.head(30)
# Out:
#     id       name    lastname           timecreate          timeupdated  age  \
# 0    1        Ted    Champion  2022-02-23 12:27:00  2022-02-23 12:48:00   50
# 1    2    Refugio  Swearingen  2022-02-23 12:27:00                 None   62
# 2    3  Johnathan       Parra  2022-02-23 12:27:00                 None   28
# 3    4     Gussie      Kelley  2022-02-23 12:27:00                 None   21
# 4    5     Susana      Camara  2022-02-23 12:27:00                 None   69
# 5    6    Freeman     Worrell  2022-02-23 12:27:00                 None   52
# 6    7       Joan     Montero  2022-02-23 12:27:00                 None   62
# 7    8  Zachariah     Metzger  2022-02-23 12:27:00                 None   66
# 8    9      Raven     Batiste  2022-02-23 12:27:00                 None   48
# 9   10     Kathie     Vandyke  2022-02-23 12:27:00                 None   68
# 10  11  Adalberto     Clemons  2022-02-23 12:27:00                 None   28
# ...
